# %%
import os 
from os.path import join,abspath
import scipy.io as sio
import numpy as np

from utils.get_feedback_blocks import get_feedback_blocks
from utils.get_response_onsets import get_response_onsets

# %%
log_dir      = "/home/rantanplan/Documents/Paris/HEART_PPI/heart_logs/"
mat_dir      = "/home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/"
onset_dir    = "/home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/RESPONSE/"
feedback_dir = "/home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/"

mapping = dict(GS248="sub_01",
               CM249="sub_02",
               WT250="sub_03",
               XA251="sub_04",
               GS252="sub_05",
               LT253="sub_06",
               MU254="sub_07",
               CG255="sub_08",
               PJ256="sub_09",
               EM257="sub_10",
               YJ258="sub_11",
               GA259="sub_12",
               AF260="sub_13",
               MT261="sub_14",
               CL262="sub_15",
               CG263="sub_16",
               TW265="sub_17",
               BP267="sub_18",
               CS268="sub_19",
               TC269="sub_20")

# %%
### Loop through folder with mat files and extract onsets and durations for each of the two
### feedback conditions (Synchronous / Asynchronous)

for root, dirs, files in os.walk(mat_dir):
    for name in files:
        mat = join(root, name)

        if mat.endswith(".mat"):
            mat_file = sio.loadmat(mat)

            if "task_type" in mat_file.keys():
                if 'MINEOTHER' in mat_file["task_type"]:

                    blocks = get_feedback_blocks(mat)
                    print(blocks["name"])
                    print(blocks["sync_onset"], "----- Len: {}".format(len(blocks["sync_onset"])))
                    print(blocks["sync_duration"],"----- Len: {}".format(len(blocks["sync_duration"])))
                    print(blocks["async_onset"],"----- Len: {}".format(len(blocks["async_onset"])))
                    print(blocks["async_duration"],"----- Len: {}".format(len(blocks["async_duration"])))
                    output_name = join(feedback_dir, mapping[mat[-9:-7]+mat[-12:-9]]+ "_feedback.mat")
                    print(output_name+ "\n")
                    sio.savemat(output_name,{"feedback":blocks})
# Out:
# 263CG
# [  8  79 112 157 195 226 281 314 365] ----- Len: 9
# [23 17 13 36 14 17 16 33 13] ----- Len: 9
# [ 32  47  63  97 126 139 210 244 298 348 380] ----- Len: 11
# [13 14 15 14 11 17 15 36 15 16 31] ----- Len: 11
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_16_feedback.mat
#
# 250WT
# [  5 175 207 304 352 400] ----- Len: 6
# [21 18 20 23 19 32] ----- Len: 6
# [ 28  73  96 112 229 251 276 330 373 434 462 495 533] ----- Len: 13
# [43 20 14 61 20 23 17 20 25 25 31 36  1] ----- Len: 13
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_03_feedback.mat
#
# 258YJ
# [ 63 112 136 160 206 223 370 443 495] ----- Len: 9
# [21 22 22 25 15 17 45 23 55] ----- Len: 9
# [ 25 187 241 291 352 416 478] ----- Len: 7
# [36 18 48 17 17 26 16] ----- Len: 7
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_11_feedback.mat
#
# 249CM
# [  9  28  84 132 180 198 287 328 375 416 460 495] ----- Len: 12
# [17 12 14 22 15 21 22 23 21 42 31 19] ----- Len: 12
# [ 42 100 156 220 239 310 353 397] ----- Len: 8
# [41 22 22 17 25 16 20 18] ----- Len: 8
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_02_feedback.mat
#
# 267BP
# [ 17  53  99 116 156 196 227 257 316 347 397] ----- Len: 11
# [33 13 15 18 20 29 28 37 16 11 16] ----- Len: 11
# [ 67  81 135 177 296 333 359 414 454] ----- Len: 9
# [12 17 19 18 19 12 36 38  3] ----- Len: 9
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_18_feedback.mat
#
# 262CL
# [  7  21  49 126 182 220 235 292 319] ----- Len: 9
# [12 10 21 35 22 13 27  9 24] ----- Len: 9
# [ 33  72 104 163 205 263 302 344] ----- Len: 8
# [15 30 15 18 14 27 15  7] ----- Len: 8
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_15_feedback.mat
#
# 253LT
# [  4  16  91 122 188 264 318] ----- Len: 7
# [10 15 29 48 15 10 15] ----- Len: 7
# [ 32  60 171 204 247 276 288 302 334 349 362 378] ----- Len: 12
# [26 28 16 41 15 10 12 14 13 11 14  2] ----- Len: 12
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_06_feedback.mat
#
# 265TW
# [ 15  46  80 158 192 226 238 249 319 365] ----- Len: 10
# [12 31 15 14 12 10  9 30 10 12] ----- Len: 10
# [ 29  79  96 114 144 173 206 281 331 378 418] ----- Len: 11
# [15  0 15 27 12 17 18 37 32 38  1] ----- Len: 11
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_17_feedback.mat
#
# 265TW
# [ 11  39 101 116 128 161 194 206 276 354] ----- Len: 10
# [12 25 13  0 15 13 10 28 16 12] ----- Len: 10
# [ 25  66  83 117 144 177 235 250 264 293 307 323 368] ----- Len: 13
# [12 15 16  9 15 14 13 12 11 12 14 30 16] ----- Len: 13
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_17_feedback.mat
#
# 268CS
# [ 11 138 185 281 298 339 367 452 475 513 531] ----- Len: 11
# [48 19 22 15 20 26 50 21 36 16 19] ----- Len: 11
# [ 61  90 118 159 209 230 253 319 418] ----- Len: 9
# [26 25 19 24 19 21 26 19 19] ----- Len: 9
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_19_feedback.mat
#
# 248GS
# [  9  44  99 117 194 278 331 341 382] ----- Len: 9
# [16 14 16 25 14 31  8 24 49] ----- Len: 9
# [ 28  60 143 179 209 255 311 367] ----- Len: 8
# [14 38 34 14 44 21 18 13] ----- Len: 8
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_01_feedback.mat
#
# 269TC
# [ 19  39 135 198 269 333 394 444 466 516] ----- Len: 10
# [18 17 19 23 23 18 21 20 48 16] ----- Len: 10
# [ 58  82 109 156 175 222 242 294 352 371 417 534] ----- Len: 12
# [21 25 23 17 19 18 26 37 17 20 25 16] ----- Len: 12
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_20_feedback.mat
#
# 261MT
# [ 17  63 102 141 335 388] ----- Len: 6
# [15 20 18 14 20 19] ----- Len: 6
# [ 33  84 121 157 209 261 356 409 430 463] ----- Len: 10
# [28 17 18 50 50 73 30 19 31  2] ----- Len: 10
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_14_feedback.mat
#
# 260AF
# [ 12  73 161 181 360 426 441] ----- Len: 7
# [17 17 18 13 30 13 20] ----- Len: 7
# [ 31  91 142 215 319 392 407 462 484] ----- Len: 9
# [ 40  49  17 102  39  13  16  20   1] ----- Len: 9
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_13_feedback.mat
#
# 254MU
# [ 11  65 170 291 388] ----- Len: 5
# [ 33  49 103  32  16] ----- Len: 5
# [ 45 115 135 274 324 405 424] ----- Len: 7
# [19 18 33 16 62 17 20] ----- Len: 7
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_07_feedback.mat
#
# 255CG
# [ 10  27  56  94 110 195 245 263 369 385 403] ----- Len: 11
# [ 15  15  19  13  12  48  16 104  14  15  12] ----- Len: 11
# [ 76 124 182 416] ----- Len: 4
# [16 56 11 14] ----- Len: 4
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_08_feedback.mat
#
# 256PJ
# [ 14  48  81 117 135 150 222 278 299 321 382 449] ----- Len: 12
# [17 14 19 15 13 16 18 19 20 39 14 21] ----- Len: 12
# [ 34  65 102 168 188 207 242 260 361 398 414 432] ----- Len: 12
# [13 14 14 16 17 13 16 15 19 14 16 16] ----- Len: 12
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_09_feedback.mat
#
# 257EM
# [  5  19  32  89 106 135 191 207 220 256 296] ----- Len: 11
# [12 11 11 15 14 12 14 11  9 28 15] ----- Len: 11
# [ 44 122 149 179 231 285 312 324 341] ----- Len: 9
# [44 11 28 10 23 10 10 15 16] ----- Len: 9
# /home/rantanplan/Documents/Paris/HEART_PPI/heart_vectors/FEEDBACK/sub_10_feedback.mat

# %%
for root, dirs, files in os.walk(mat_dir):
    for name in files:
        mat = join(root, name)

        if mat.endswith(".mat"):
            mat_file = sio.loadmat(mat)

            if "task_type" in mat_file.keys():
                if 'MINEOTHER' in mat_file["task_type"]:

                    onsets = get_response_onsets(mat)
                    print(onsets["name"])
                    print(onsets["mine_onset"])
                    print(onsets["other_duration"])
          
                    output_name = join(onset_dir, mapping[mat[-9:-7]+mat[-12:-9]]+ "_response.mat")
                    print(output_name+ "\n")
                    sio.savemat(output_name,{"responses":blocks})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-eec4f095e8a6> in <module>
#       9                 if 'MINEOTHER' in mat_file["task_type"]:
#      10
# ---> 11                     onsets = get_response_onsets(mat)
#      12                     print(onsets["name"])
#      13                     print(onsets["mine_onset"])
#
# ~/Documents/Paris/HEART_PPI/heart_PPI_code/PPI_analysis/utils/get_response_onsets.py in get_response_onsets(mat_file)
#      31     other_onset = []
#      32     for onset in onsets:
# ---> 33         if mat["response"][onset] == "Mine ":
#      34             mine_onset.append(onset)
#      35         else:
#
# IndexError: index 411 is out of bounds for axis 0 with size 411
